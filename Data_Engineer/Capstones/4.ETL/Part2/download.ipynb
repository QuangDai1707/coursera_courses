# %%
# !python --version

# %%
# !pip install "apache-airflow[celery]==2.10.3" --constraint "https://raw.githubusercontent.com/apache/airflow/constraints-2.10.3/constraints-3.8.txt"

# %%
pip install --upgrade setuptools wheel

# %%
pip install --upgrade pip

# %%
pip install dill

# %%
pip install apache-airflow[celery]==2.10.3 --use-pep517

# %%
pip download dill --no-binary :all:

# %%
# !tar -xzf dill-*.tar.gz

# %%
# !python dill-0.3.9/setup.py --help

# %%
pip install apache-airflow==2.9.0
# Out:
# ...
#   Using cached apache_airflow-2.9.0-py3-none-any.whl.metadata (43 kB)
# ...
#   Using cached alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# ...
#   Using cached argcomplete-3.5.1-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# ...
#   Using cached colorlog-4.8.0-py2.py3-none-any.whl.metadata (9.8 kB)
# ...
#   Using cached ConfigUpdater-3.2-py2.py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached connexion-2.14.2-py2.py3-none-any.whl.metadata (28 kB)
# ...
#   Using cached cron_descriptor-1.4.5-py3-none-any.whl.metadata (5.7 kB)
# ...
#   Using cached croniter-5.0.1-py2.py3-none-any.whl.metadata (30 kB)
# ...
#   Using cached Deprecated-1.2.15-py2.py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached Flask_Caching-2.3.0-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached flask_session-0.5.0-py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached flask_wtf-1.2.2-py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached Flask-2.2.5-py3-none-any.whl.metadata (3.9 kB)
# ...

# %%
import airflow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/5n/fk6vlwt16d10hw1ydjzw3f6m0000gn/T/ipykernel_13744/945934463.py in <module>
# ----> 1 import airflow
#
# ModuleNotFoundError: No module named 'airflow'
